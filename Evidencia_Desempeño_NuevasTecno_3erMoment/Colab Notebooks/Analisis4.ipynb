# %%
import pandas as pd
import matplotlib as mpl
import numpy as np

# %%
datos = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Alquiler_viviendas_clean.csv', sep = ';')

# %%
datos.head(30)
# Out:
#     Unnamed: 0                Tipo     Distrito  Cuartos  Vacantes  Suites  \
# 0            0          Habitación    San Borja        1         0       0
# 1            1                Casa   Lurigancho        2         0       1
# 2            2     Local comercial          Ate        0         4       0
# 3            3        Departamento   Pachacámac        1         0       0
# 4            4        Departamento          Ate        1         0       0
# 5            5        Departamento     Barranco        3         1       0
# 6            6        Departamento        Comas        2         0       0
# 7            7  Casa en condominio          Ate        5         4       5
# 8            8  Casa en condominio  El Agustino        2         2       0
# 9            9     Local comercial   Pachacámac        0         3       0
# 10          10        Departamento   Pachacámac        1         0       0
# 11          11        Departamento      Mi Perú        2         1       0
# 12          12        Departamento    San Borja        3         1       1
# 13          13        Departamento    San Borja        1         0       1
# 14          14          Habitación    San Borja        1         0       0
# 15          15        Departamento    San Borja        4         3       1
# 16          16   Edificio completo   Chorrillos        0         0       0
# 17          17                Flat   Chorrillos        3         1       1
# 18          18  Casa en condominio     San Luis        3         1       1
# 19          19        Departamento       Callao        3         0       0
# 20          20        Departamento          Ate        2         1       1
# 21          21        Departamento   San Miguel        2         1       0
# 22          22  Casa en condominio          Ate        4         3       2
# 23          23        Departamento   Santa Rosa        3         1       0
# 24          24        Departamento   San Miguel        2         1       0
# 25          25                Flat        Rímac        1         0       0
# 26          26     Local comercial  Punta Negra        0         1       0
# 27          27        Departamento        Comas        3         1       1
# 28          28        Departamento   San Miguel        1         0       0
# 29          29        Tienda/Salón        Lince        0         1       0
#
#     Area    Valor  Mantenimiento  Impuesto
# 0     40   1700.0          500.0      60.0
# 1    100   7000.0            0.0       0.0
# 2    150   5200.0         4020.0    1111.0
# 3     15    800.0          390.0      20.0
# 4     48    800.0          230.0       0.0
# 5     70   1200.0            0.0       0.0
# 6     50   1300.0          301.0      17.0
# 7    750  22000.0            0.0       0.0
# 8     65   1000.0            0.0       0.0
# 9    695  35000.0        19193.0    3030.0
# 10    36   1200.0            0.0       0.0
# 11    70   1500.0          642.0      74.0
# 12    90   1500.0          455.0      14.0
# 13    40   2000.0          561.0      50.0
# 14    27   1800.0          501.0       0.0
# 15   243  13000.0         2000.0     803.0
# 16   536  28000.0            0.0    3563.0
# 17    80   3800.0         1040.0       0.0
# 18   115   2000.0            0.0       0.0
# 19    54    950.0          300.0      28.0
# 20    67   1700.0          589.0     147.0
# 21   110   1900.0          700.0     138.0
# 22   466   7500.0         2695.0       0.0
# 23    68   1000.0          670.0       0.0
# 24    78   2000.0          700.0       0.0
# 25    56   4500.0         1900.0    1500.0
# 26    25   1100.0          600.0       0.0
# 27   125   7000.0         2100.0     463.0
# 28    48    750.0          772.0      25.0
# 29    35   1300.0          950.0       0.0

# %%
datos.shape[0]
# Out:
# 32673

# %%
datos['Valor'].mean()
# Out:
# 12985.629082116733

# %%
datos['Mantenimiento']
# Out:
# 0         500.0
# 1           0.0
# 2        4020.0
# 3         390.0
# 4         230.0
#           ...
# 32668     350.0
# 32669     800.0
# 32670     509.0
# 32671     760.0
# 32672    4206.0
# Name: Mantenimiento, Length: 32673, dtype: float64

# %%
datos['Mantenimiento'].std()
# Out:
# 36839.94022121286

# %%
np.sqrt(datos['Mantenimiento'].std())
# Out:
# 191.93733409947336

# %%
datos.describe()
# Out:
#          Unnamed: 0       Cuartos      Vacantes        Suites          Area  \
# count  32673.000000  32673.000000  32673.000000  32673.000000  32673.000000
# mean   16346.596242      1.781961      1.711505      0.668717    228.107581
# std     9436.172097      1.701733     19.581792      1.163777   1074.718091
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     8176.000000      0.000000      0.000000      0.000000     55.000000
# 50%    16348.000000      2.000000      1.000000      0.000000     88.000000
# 75%    24518.000000      3.000000      2.000000      1.000000    170.000000
# max    32688.000000    100.000000   1966.000000     70.000000  90000.000000
#
#               Valor  Mantenimiento      Impuesto
# count  3.267300e+04   3.267300e+04  3.267300e+04
# mean   1.298563e+04   2.098068e+03  1.635902e+03
# std    6.702669e+05   3.683994e+04  1.497497e+05
# min    7.500000e+01   0.000000e+00  0.000000e+00
# 25%    1.500000e+03   4.500000e+02  0.000000e+00
# 50%    2.800000e+03   8.500000e+02  1.200000e+02
# 75%    6.500000e+03   1.630000e+03  4.200000e+02
# max    1.200000e+08   6.552570e+06  2.705307e+07

# %%
list(['Distrito'])
# Out:
# ['Distrito']

# %%
list(datos['Distrito'].drop_duplicates())
# Out:
# ['San Borja',
#  'Lurigancho',
#  'Ate',
#  'Pachacámac',
#  'Barranco',
#  'Comas',
#  'El Agustino',
#  'Mi Perú',
#  'Chorrillos',
#  'San Luis',
#  'Callao',
#  'San Miguel',
#  'Santa Rosa',
#  'Rímac',
#  'Punta Negra',
#  'Lince',
#  'Jesús María',
#  'Miraflores',
#  'Breña',
#  'Ancón',
#  'Santa Anita',
#  'Villa María del Triunfo',
#  'Villa El Salvador',
#  'Punta Hermosa',
#  'La Perla',
#  'San Juan de Lurigancho',
#  'Chaclacayo',
#  'Pueblo Libre',
#  'Puente Piedra',
#  'Lurín',
#  'La Punta',
#  'Ventanilla',
#  'Magdalena del Mar',
#  'Santa María del Mar',
#  'Bellavista',
#  'San Martín de Porres',
#  'Santiago de Surco',
#  'San Juan de Miraflores',
#  'San Isidro',
#  'San Bartolo',
#  'Carmen de La Legua',
#  'Los Olivos',
#  'Pucusana',
#  'La Molina',
#  'Cieneguilla',
#  'Lima',
#  'Independencia',
#  'Surquillo',
#  'La Victoria',
#  'Carabayllo']

# %%
# Barranco->1555.22
# Callao->4750.5
# Comas->9701.07
# El Agustino->89729.72
# Lince->105894.8
# San Luis->3756.12

# %%
grupo_barrio[['Valor','Mantenimiento','Impuesto']].mean().round(2)
# Out:
#                  Valor  Mantenimiento  Impuesto
# Distrito
# Ate            8956.22        3420.07   1507.83
# Barranco       1555.22         344.53    104.64
# Callao         4750.50         666.82    325.93
# Comas          9701.07        2085.07    815.48
# El Agustino   89729.72         613.73   1133.72
# Lince        105894.80         573.76    175.39
# San Luis       3756.12         446.92    378.39
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Valor'].plot(kind='hist', bins=20, title='Valor')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Mantenimiento'].plot(kind='hist', bins=20, title='Mantenimiento')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Impuesto'].plot(kind='hist', bins=20, title='Impuesto')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='Valor', y='Mantenimiento', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Mantenimiento', y='Impuesto', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Valor'].plot(kind='line', figsize=(8, 4), title='Valor')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['Mantenimiento'].plot(kind='line', figsize=(8, 4), title='Mantenimiento')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['Impuesto'].plot(kind='line', figsize=(8, 4), title='Impuesto')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
grupo_barrio['Valor'].describe().round(2)
# Out:
#               count       mean         std    min     25%     50%      75%  \
# Distrito
# Ate          6283.0    8956.22    30131.44  100.0  2000.0  3500.0   8000.0
# Barranco       90.0    1555.22     2055.89  400.0   712.5   975.0   1200.0
# Callao        718.0    4750.50    36833.05  300.0  1000.0  1500.0   2200.0
# Comas        2423.0    9701.07    19955.72  100.0  3500.0  6500.0  10500.0
# El Agustino   185.0   89729.72  1102670.89  500.0   850.0  1100.0   2000.0
# Lince        1184.0  105894.80  3487339.32  100.0   800.0  1200.0   2000.0
# San Luis      596.0    3756.12     8329.09   75.0   990.0  1325.0   2200.0
#
#                      max
# Distrito
# Ate             738197.0
# Barranco         12000.0
# Callao          800000.0
# Comas           800000.0
# El Agustino   15000000.0
# Lince        120000000.0
# San Luis         79000.0

# %%
grupo_barrio['Valor'].aggregate(['min', 'max']).rename(columns={'min':'minimo','max': 'maximo'})
# Out:
#              minimo       maximo
# Distrito
# Ate           100.0     738197.0
# Barranco      400.0      12000.0
# Callao        300.0     800000.0
# Comas         100.0     800000.0
# El Agustino   500.0   15000000.0
# Lince         100.0  120000000.0
# San Luis       75.0      79000.0

# %% [markdown]
# *VISUALIZACION*

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure',figsize = (20,10))

# %%
fig = grupo_barrio['Valor'].mean().plot.bar(color = 'grey')
fig.set_ylabel('Valor Alquiler')
fig.set_title('Valor promeio alquiler por distrito',{'fontsize':22})
# Out:
# Text(0.5, 1.0, 'Valor promeio alquiler por distrito')

# %%
fig = grupo_barrio['Valor'].max().plot.line(color = 'pink')
fig.set_ylabel('Valor Alquiler')
fig.set_title("Valor maximo por Distrito")
# Out:
# Text(0.5, 1.0, 'Valor maximo por Distrito')
