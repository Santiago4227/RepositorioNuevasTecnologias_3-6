# %%
import pandas as pd

# %%
datos_viviendas = pd.read_csv('/content/drive/MyDrive/alquileres_viviendas.csv', sep = ';')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#seleccione tipo "Departamento"
sel_departamento = datos_viviendas['Tipo'] == 'Departamento'
n1 = datos_viviendas[sel_departamento].shape[0]
n1
# Out:
# 19532

# %%
seleccion = (datos_viviendas['Tipo'] == 'Casa') | (datos_viviendas['Tipo']=='Habitación')
n2 = datos_viviendas[seleccion].shape[0]
n2
# Out:
# 1803

# %%
sel_areas = (datos_viviendas['Area']>= 60) & (datos_viviendas ['Area'] <= 100)
n3 = datos_viviendas[sel_areas].shape[0]
n3
# Out:
# 10187

# %%
#Cuartos 4 y alquiler < 2000
selec_cuartos_alquiler = (datos_viviendas['Cuartos']>= 4) & (datos_viviendas['Valor']<= 2000)
n4 = datos_viviendas[selec_cuartos_alquiler].shape[0]
n4
# Out:
# 62

# %%
print(f"El numero de departamentos es de {n1}")
print (f"El numero de Casas y habitaciones encontradas es de {n2}")
print (f"El numero de viviendas con un areas entre 60 y 100 nts cuadrados es de  {n3}")
print (f"En numero de viviendas que tengan al menos 4 habitaciones y cuestan menos de 2000 {n4}")
# Out:
# El numero de departamentos es de 19532
# El numero de Casas y habitaciones encontradas es de 1803
# El numero de viviendas con un areas entre 60 y 100 nts cuadrados es de  10187
# En numero de viviendas que tengan al menos 4 habitaciones y cuestan menos de 2000 62

# %%
datos_viviendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           32960 non-null  object
#  1   Distrito       32960 non-null  object
#  2   Cuartos        32960 non-null  int64
#  3   Vacantes       32960 non-null  int64
#  4   Suites         32960 non-null  int64
#  5   Area           32960 non-null  int64
#  6   Valor          32943 non-null  float64
#  7   Mantenimiento  28867 non-null  float64
#  8   Impuesto       22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
datos_viviendas[datos_viviendas['Valor'].isnull()]
# Out:
#                              Tipo     Distrito  Cuartos  Vacantes  Suites  \
# 76                   Departamento          Ate        2         1       1
# 2186                 Departamento  San Bartolo        2         0       0
# 2456                         Casa        Lince        3         4       3
# 2646                 Tienda/Salón          Ate        0         2       0
# 2941                 Departamento   Chorrillos        2         0       0
# 2973                 Departamento    San Borja        2         0       0
# 6598                 Tienda/Salón     La Punta        0         0       0
# 7302                         Casa        Lince        3         2       1
# 12683                Departamento  San Bartolo        2         0       1
# 13229                Departamento     La Punta        3         0       1
# 13525                Departamento     La Perla        3         1       1
# 13579             Local comercial   Chorrillos        0         3       0
# ...

# %%
vivienda_nan = datos_viviendas.shape[0]
datos_viviendas.dropna(subset = ['Valor'],inplace= True)
vivienda_nan_b = datos_viviendas.shape[0]
vivienda_nan - vivienda_nan_b
# Out:
# 17

# %%
datos_viviendas[datos_viviendas['Valor'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Distrito, Cuartos, Vacantes, Suites, Area, Valor, Mantenimiento, Impuesto]
# Index: []

# %%
datos_viviendas[datos_viviendas['Mantenimiento'].isnull()].shape[0]
# Out:
# 4089

# %%
seleccion_dep = (datos_viviendas['Tipo'] == 'Departamento')&(datos_viviendas['Mantenimiento'].isnull())

# %%
sel_A = datos_viviendas.shape[0]
datos_viviendas = datos_viviendas[~seleccion_dep]
sel_B = datos_viviendas.shape[0]
sel_A - sel_B
# Out:
# <ipython-input-31-e852fbd2cf05>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   datos_viviendas = datos_viviendas[~seleccion_dep]
# 745

# %%
datos_viviendas[datos_viviendas['Mantenimiento'].isnull()].shape[0]
# Out:
# 0

# %%
datos_viviendas = datos_viviendas.fillna({'Mantenimiento':0, 'Impuesto':0})

# %%
datos_viviendas[datos_viviendas['Mantenimiento'].isnull()].shape[0]
# Out:
# 0

# %%
datos_viviendas[datos_viviendas['Impuesto'].isnull()].shape[0]
# Out:
# 0

# %%
datos_viviendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           0 non-null      object
#  1   Distrito       0 non-null      object
#  2   Cuartos        0 non-null      int64
#  3   Vacantes       0 non-null      int64
#  4   Suites         0 non-null      int64
#  5   Area           0 non-null      int64
#  6   Valor          0 non-null      float64
#  7   Mantenimiento  0 non-null      float64
#  8   Impuesto       0 non-null      float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 0.0+ bytes

# %%
datos_viviendas.to_csv ('Alquiler_viviendas_clean.csv', sep=';', index=False)
