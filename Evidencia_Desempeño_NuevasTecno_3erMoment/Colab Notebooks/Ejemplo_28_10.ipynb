# %%
import numpy as np
import matplotlib as mpl
import pandas as ps

# %%
import pandas as ps

# %%
ps = ps.read_csv('ejemplo.csv')

# %%
print (ps)
# Out:
#   profeso,aula,nivel
# 0         Juan,503,1
# 1        Pedro,402,2
# 2       Felipe,302,4
