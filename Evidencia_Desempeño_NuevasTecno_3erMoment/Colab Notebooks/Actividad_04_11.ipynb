# %%
import pandas as pd

# %%
titulos_m = pd.read_csv("titulo.csv")

# %%
names_m = pd.read_excel("name.xlsx")

# %%
Taller_m = pd.read_json("Taller_motos.json")

# %%
Taller = pd.concat([titulos_m, names_m, Taller_m], ignore_index=True)

# %%
Taller
# Out:
#          Moto      color modelo cilindraje
# 0       Mt-09       gris   2023      890cc
# 1       dr650   amarillo   2019      644cc
# 2       xt660       azul   2021      660cc
# 3      xtz250     blanco   2023      249cc
# 4   pulsar200       rojo   2022      199cc
# 5  dominar400      negro   2022      373cc
# 6      kmx125      verde   2006      125cc
# 7       mt-09       gris   2023      890cc
# 8       dr650   amarillo   2019      644cc
# 9      kmx125      verde   2006      125cc
