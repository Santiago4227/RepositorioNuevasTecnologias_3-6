# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv('alquiler.csv', sep=';')

# %%
df
# Out:
#                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0           Habitación   San Borja        1         0       0    40  1700.0
# 1                 Casa  Lurigancho        2         0       1   100  7000.0
# 2      Local comercial         Ate        0         4       0   150  5200.0
# 3         Departamento  Pachacámac        1         0       0    15   800.0
# 4         Departamento         Ate        1         0       0    48   800.0
# ...                ...         ...      ...       ...     ...   ...     ...
# 32955       Habitación  Pachacámac        0         0       0    27   800.0
# 32956     Departamento       Lince        3         1       2    78  1800.0
# 32957     Departamento       Rímac        2         1       0    48  1400.0
# 32958     Departamento       Rímac        2         0       0    70  3000.0
# 32959  Local comercial  Pachacámac        0         0       0   250  6500.0
#
#        Mantenimiento  Impuesto
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           32960 non-null  object
#  1   Distrito       32960 non-null  object
#  2   Cuartos        32960 non-null  int64
#  3   Vacantes       32960 non-null  int64
#  4   Suites         32960 non-null  int64
#  5   Area           32960 non-null  int64
#  6   Valor          32943 non-null  float64
#  7   Mantenimiento  28867 non-null  float64
#  8   Impuesto       22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
df.describe()
# Out:
#             Cuartos      Vacantes        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#        Mantenimiento      Impuesto
# count   2.886700e+04  2.272300e+04
# mean    2.388062e+03  2.364410e+03
# std     3.918496e+04  1.795641e+05
# min     1.000000e+00  1.000000e+00
# 25%     5.900000e+02  1.100000e+02
# 50%     9.900000e+02  2.500000e+02
# ...

# %%
df.head(5)
# Out:
#               Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0       Habitación   San Borja        1         0       0    40  1700.0
# 1             Casa  Lurigancho        2         0       1   100  7000.0
# 2  Local comercial         Ate        0         4       0   150  5200.0
# 3     Departamento  Pachacámac        1         0       0    15   800.0
# 4     Departamento         Ate        1         0       0    48   800.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# 4          230.0       NaN

# %%
df.tail(5)
# Out:
#                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 32955       Habitación  Pachacámac        0         0       0    27   800.0
# 32956     Departamento       Lince        3         1       2    78  1800.0
# 32957     Departamento       Rímac        2         1       0    48  1400.0
# 32958     Departamento       Rímac        2         0       0    70  3000.0
# 32959  Local comercial  Pachacámac        0         0       0   250  6500.0
#
#        Mantenimiento  Impuesto
# 32955          350.0      25.0
# 32956          800.0      40.0
# 32957          509.0      37.0
# 32958          760.0       NaN
# 32959         4206.0    1109.0

# %%
df[['Tipo', 'Area']]
# Out:
#                   Tipo  Area
# 0           Habitación    40
# 1                 Casa   100
# 2      Local comercial   150
# 3         Departamento    15
# 4         Departamento    48
# ...                ...   ...
# 32955       Habitación    27
# 32956     Departamento    78
# 32957     Departamento    48
# 32958     Departamento    70
# 32959  Local comercial   250
#
# [32960 rows x 2 columns]

# %%
viviendas_peq = df[df['Area']<60]

# %%
viviendas_peq
# Out:
#                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0           Habitación   San Borja        1         0       0    40  1700.0
# 3         Departamento  Pachacámac        1         0       0    15   800.0
# 4         Departamento         Ate        1         0       0    48   800.0
# 6         Departamento       Comas        2         0       0    50  1300.0
# 10        Departamento  Pachacámac        1         0       0    36  1200.0
# ...                ...         ...      ...       ...     ...   ...     ...
# 32948  Local comercial  Pachacámac        0         0       0    32   600.0
# 32950     Departamento  San Miguel        1         0       0    28  1000.0
# 32951     Departamento         Ate        2         0       0    52  1000.0
# 32955       Habitación  Pachacámac        0         0       0    27   800.0
# 32957     Departamento       Rímac        2         1       0    48  1400.0
#
#        Mantenimiento  Impuesto
# ...

# %%
viviendas_grandes = df[df['Area']>=60]

# %%
viviendas_grandes
# Out:
#                      Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 1                    Casa   Lurigancho        2         0       1   100
# 2         Local comercial          Ate        0         4       0   150
# 5            Departamento     Barranco        3         1       0    70
# 7      Casa en condominio          Ate        5         4       5   750
# 8      Casa en condominio  El Agustino        2         2       0    65
# ...                   ...          ...      ...       ...     ...   ...
# 32953        Departamento  Santa Anita        2         0       0    70
# 32954             Cochera   Pachacámac        0         0       0   755
# 32956        Departamento        Lince        3         1       2    78
# 32958        Departamento        Rímac        2         0       0    70
# 32959     Local comercial   Pachacámac        0         0       0   250
#
#          Valor  Mantenimiento  Impuesto
# 1       7000.0            NaN       NaN
# ...

# %%
viviendas_medianas = df[(df['Area']> 60) & (df['Area'] <= 100)]

# %%
viviendas_medianas
# Out:
#                      Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 1                    Casa   Lurigancho        2         0       1   100
# 5            Departamento     Barranco        3         1       0    70
# 8      Casa en condominio  El Agustino        2         2       0    65
# 11           Departamento      Mi Perú        2         1       0    70
# 12           Departamento    San Borja        3         1       1    90
# ...                   ...          ...      ...       ...     ...   ...
# 32944        Departamento  Jesús María        3         2       1    88
# 32947        Departamento        Rímac        3         0       1    80
# 32953        Departamento  Santa Anita        2         0       0    70
# 32956        Departamento        Lince        3         1       2    78
# 32958        Departamento        Rímac        2         0       0    70
#
#         Valor  Mantenimiento  Impuesto
# 1      7000.0            NaN       NaN
# ...

# %%
df_area = viviendas_medianas.groupby(['Tipo','Area'])

# %%
df_area.count()
# Out:
#                    Distrito  Cuartos  Vacantes  Suites  Valor  Mantenimiento  \
# Tipo         Area
# Almacén      71           1        1         1       1      1              0
#              92           1        1         1       1      1              0
#              95           1        1         1       1      1              0
#              100          6        6         6       6      6              1
# Casa         61           2        2         2       2      2              1
# ...                     ...      ...       ...     ...    ...            ...
# Tienda/Salón 96           4        4         4       4      4              2
#              97           1        1         1       1      1              1
#              98           4        4         4       4      4              3
#              99           1        1         1       1      1              1
#              100         53       53        53      53     53             33
#
# ...

# %%
df_area.sample()
# Out:
#                Tipo             Distrito  Cuartos  Vacantes  Suites  Area  \
# 14955       Almacén                  Ate        0         0       0    71
# 26769       Almacén  Santa María del Mar        4         4       0    92
# 4291        Almacén                Breña        0         0       0    95
# 12260       Almacén           Chaclacayo        0         2       0   100
# 25633          Casa    Villa El Salvador        2         1       0    61
# ...             ...                  ...      ...       ...     ...   ...
# 13415  Tienda/Salón                Lince        0         0       0    96
# 27081  Tienda/Salón                  Ate        0         1       0    97
# 2236   Tienda/Salón          Jesús María        0         0       0    98
# 24861  Tienda/Salón                  Ate        0         1       0    99
# 12579  Tienda/Salón        Independencia        0         0       0   100
#
#         Valor  Mantenimiento  Impuesto
# 14955  2500.0            NaN      60.0
# ...

# %%
df_area = viviendas_medianas.groupby('Tipo')[['Area']].count()

# %%
df_area
# Out:
#                             Area
# Tipo
# Almacén                        9
# Casa                         224
# Casa comercial                16
# Casa de villa                 79
# Casa en condominio           102
# Departamento                7570
# Edificio completo              2
# Flat                         214
# Habitación                     4
# Local comercial              699
# Loft                          13
# Tienda en Centro Comercial    53
# Tienda/Salón                 280

# %%
df_area = viviendas_medianas.groupby('Tipo')[['Area']].count()
